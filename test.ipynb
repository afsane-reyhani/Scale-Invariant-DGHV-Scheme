# %%
import import_ipynb
import SIDGHV
# Out:
# importing Jupyter notebook from SIDGHV.ipynb

# %% [markdown]
# # keygenaration

# %%
λ=1
j=SIDGHV.keygeneration(λ)
λ=j[0]
L=j[1]
ρ=j[2]
η=j[3]
γ=j[4]
τ=j[5]
θ=j[6]
x_0=j[7]
x=j[8]
q_0=j[9]
p=j[10]
Y=j[11]
σ=j[12]
S=j[13]
Z=j[14]
# Out:
# enter security parameter5
# λ 5
# enter multiplicative depth3
# L 3
# ρ 10
# η 8
# γ 70
# τ 80
# θ 15
# Random integer from 2^(η-1) to 2^(η)
# secret key:  219
# q_0 21271747770793701
# ...

# %% [markdown]
# # plaintext

# %%
n=1
m=SIDGHV.plaintext(n)
# Out:
# Enter number of elements : 2
# plaintext [1 0]

# %% [markdown]
# # encryption

# %%
c=SIDGHV.enc(m,x,x_0,θ,Y,τ)
# Out:
# ciphertext [150587356120783291866, 4786563633813713592]
# SIDGHV.ipynb:8: RuntimeWarning: overflow encountered in longlong_scalars
#   "source": [

# %% [markdown]
# # decryption

# %%
d=SIDGHV.dec(c,p)
# Out:
# decription [1, 1]

# %% [markdown]
# # error decryption

# %%
SIDGHV.error(d,m)
# Out:
# error 1

# %% [markdown]
# # ADD

# %%
SIDGHV.ADD(c,p,m,x_0)
# Out:
# decription [0]
# saddc [0]
# saddm [1]
# error 1
# None

# %% [markdown]
# # mult

# %%
SIDGHV.mult(c,p,m,x,x_0,θ,Y,τ,σ,Z,η)
# Out:
# decription [0]
# mullc [0]
# mul_m [0]
# error 0
# None
